# %%
import pandas as pd

# %%
data={'Name':['Alice','Bob'],'Age':[25,30]}

# %%
df=pd.DataFrame(data)

# %%
lst=[['Alice',25],['Bob',30]]

# %%
df=pd.DataFrame(lst,columns=['Name','Age'])

# %%
df.head()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.tail()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      str
#  1   Age     2 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 164.0 bytes

# %%
df.describe()
# Out:
#              Age
# count   2.000000
# mean   27.500000
# std     3.535534
# min    25.000000
# 25%    26.250000
# 50%    27.500000
# 75%    28.750000
# max    30.000000

# %%
df['Name']
# Out:
# 0    Alice
# 1      Bob
# Name: Name, dtype: str

# %%
df[['Name','Age']]
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.loc[0]
# Out:
# Name    Alice
# Age        25
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# Name    Bob
# Age      30
# Name: 1, dtype: object

# %%
df[df['Age']>25]
# Out:
#   Name  Age
# 1  Bob   30

# %%
df['Gender']=['F','M']

# %%
df.drop('Age',axis=1,inplace=True)

# %%
df.isnull()
# Out:
#     Name  Gender
# 0  False   False
# 1  False   False

# %%
df.dropna()
# Out:
#     Name Gender
# 0  Alice      F
# 1    Bob      M

# %%
df.fillna(0)
# Out:
#     Name Gender
# 0  Alice      F
# 1    Bob      M

# %% [raw]
# df.groupby('Gender')['Age'].mean()

# %%
df1=pd.DataFrame({'key': [1, 2, 3],'Name': ['Alice', 'Bob', 'Charlie']})

# %%
df2=pd.DataFrame({'key':[1,2,3],'Age':[25,30,35]})

# %%
pd.merge(df1,df2,on='key')
# Out:
#    key     Name  Age
# 0    1    Alice   25
# 1    2      Bob   30
# 2    3  Charlie   35

# %%
df1.join(df2, lsuffix='_left', rsuffix='_right')
# Out:
#    key_left     Name  key_right  Age
# 0         1    Alice          1   25
# 1         2      Bob          2   30
# 2         3  Charlie          3   35

# %%
df=pd.read_csv("C:/Users/shrey/OneDrive/Documents/datas.csv")

# %%
df.to_csv('output.csv', index=False)

# %%
df.sort_values('Age')
# Out:
#       Name  Age gender
# 0    Alice   20      f
# 3    Padma   21      f
# 1      Bob   26      m
# 2  Charlie   27      m
# 4  Himnshu   30      m

# %%
df['Age'].apply(lambda x: x + 1)
# Out:
# 0    21
# 1    27
# 2    28
# 3    22
# 4    31
# Name: Age, dtype: int64

# %%
df['Name'].unique()
# Out:
# <StringArray>
# ['Alice', 'Bob', 'Charlie', 'Padma', 'Himnshu']
# Length: 5, dtype: str

# %%
df['Age'].value_counts()
# Out:
# Age
# 20    1
# 26    1
# 27    1
# 21    1
# 30    1
# Name: count, dtype: int64
